# %%
seed = 3906303

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


import gzip
import random
np.random.seed(seed)
random.seed(seed)

# %%
df_icu_filtered = pd.read_csv("Datagen/bg_filtered_chartevents.csv")
df_icu_filtered
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0          10000032  29079034  39553978           NaN  2180-07-23 21:45:00
# 1          10000690  25860671  37081114       84407.0  2150-11-04 10:00:00
# 2          10000690  25860671  37081114           NaN  2150-11-03 02:56:00
# 3          10000690  25860671  37081114           NaN  2150-11-04 03:03:00
# 4          10000690  25860671  37081114           NaN  2150-11-04 17:54:00
# ...             ...       ...       ...           ...                  ...
# 1814457    19999987  23865745  36195440       68756.0  2145-11-04 02:00:00
# 1814458    19999987  23865745  36195440       69532.0  2145-11-03 08:00:00
# 1814459    19999987  23865745  36195440       96092.0  2145-11-04 08:00:00
# 1814460    19999987  23865745  36195440           NaN  2145-11-03 01:35:00
# 1814461    19999987  23865745  36195440           NaN  2145-11-04 05:01:00
#
#                    storetime  itemid  value  valuenum valueuom  warning
# 0        2180-07-23 22:30:00  220621  115.0     115.0    mg/dL        1
# 1        2150-11-04 09:39:00  225664  117.0     117.0      NaN        0
# 2        2150-11-03 04:22:00  220621   77.0      77.0    mg/dL        0
# 3        2150-11-04 03:44:00  220621   84.0      84.0    mg/dL        0
# 4        2150-11-04 18:41:00  220621  120.0     120.0    mg/dL        1
# ...                      ...     ...    ...       ...      ...      ...
# 1814457  2145-11-04 05:07:00  225664  112.0     112.0      NaN        0
# 1814458  2145-11-03 07:58:00  225664  122.0     122.0      NaN        0
# 1814459  2145-11-04 08:11:00  225664  127.0     127.0      NaN        0
# 1814460  2145-11-03 02:42:00  220621  113.0     113.0    mg/dL        1
# 1814461  2145-11-04 05:51:00  220621  100.0     100.0    mg/dL        0
#
# [1814462 rows x 11 columns]

# %%
bg_icu = df_icu_filtered
bg_icu.sort_values(by=['subject_id', 'charttime'])
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0          10000032  29079034  39553978           NaN  2180-07-23 21:45:00
# 2          10000690  25860671  37081114           NaN  2150-11-03 02:56:00
# 3          10000690  25860671  37081114           NaN  2150-11-04 03:03:00
# 1          10000690  25860671  37081114       84407.0  2150-11-04 10:00:00
# 4          10000690  25860671  37081114           NaN  2150-11-04 17:54:00
# ...             ...       ...       ...           ...                  ...
# 1814458    19999987  23865745  36195440       69532.0  2145-11-03 08:00:00
# 1814456    19999987  23865745  36195440       68756.0  2145-11-03 20:00:00
# 1814457    19999987  23865745  36195440       68756.0  2145-11-04 02:00:00
# 1814461    19999987  23865745  36195440           NaN  2145-11-04 05:01:00
# 1814459    19999987  23865745  36195440       96092.0  2145-11-04 08:00:00
#
#                    storetime  itemid  value  valuenum valueuom  warning
# 0        2180-07-23 22:30:00  220621  115.0     115.0    mg/dL        1
# 2        2150-11-03 04:22:00  220621   77.0      77.0    mg/dL        0
# 3        2150-11-04 03:44:00  220621   84.0      84.0    mg/dL        0
# 1        2150-11-04 09:39:00  225664  117.0     117.0      NaN        0
# 4        2150-11-04 18:41:00  220621  120.0     120.0    mg/dL        1
# ...                      ...     ...    ...       ...      ...      ...
# 1814458  2145-11-03 07:58:00  225664  122.0     122.0      NaN        0
# 1814456  2145-11-03 20:00:00  225664  105.0     105.0      NaN        0
# 1814457  2145-11-04 05:07:00  225664  112.0     112.0      NaN        0
# 1814461  2145-11-04 05:51:00  220621  100.0     100.0    mg/dL        0
# 1814459  2145-11-04 08:11:00  225664  127.0     127.0      NaN        0
#
# [1814462 rows x 11 columns]

# %% [markdown]
# Below are some identified outliers/invalid values.

# %%
bg_icu.sort_values(by=['value'], ascending=False).head()
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 813554     14478278  29643008  30892963       94048.0  2171-11-22 22:00:00
# 449808     12468016  25074766  37541173           NaN  2138-12-11 08:46:00
# 749049     14117743  27781009  36666568           NaN  2178-08-25 01:13:00
# 901817     14988347  21377296  37919600           NaN  2138-07-19 06:40:00
# 1125680    16178097  27286024  31149549           NaN  2188-01-16 11:31:00
#
#                    storetime  itemid      value   valuenum valueuom  warning
# 813554   2171-11-23 08:40:00  225664  1653550.0  1653550.0      NaN        0
# 449808   2138-12-11 08:53:00  226537  1276100.0  1276100.0    mg/dL        1
# 749049   2178-08-27 13:26:00  220621   999999.0   999999.0      NaN        0
# 901817   2138-07-20 15:36:00  220621   999999.0   999999.0      NaN        0
# 1125680  2188-01-17 13:58:00  220621   999999.0   999999.0      NaN        0

# %%
bg_icu['charttime'] = pd.to_datetime(
    bg_icu['charttime'],
    format='%Y-%m-%d %H:%M:%S',   # matches 2180-07-23 21:45:00
    errors='raise'               # or 'coerce' to turn bad rows into NaT
)
bg_icu['storetime'] = pd.to_datetime(
    bg_icu['storetime'],
    format='%Y-%m-%d %H:%M:%S',   # matches 2180-07-23 21:45:00
    errors='raise'               # or 'coerce' to turn bad rows into NaT
)

# %%
bg_icu['valueuom'].value_counts()
# Out:
# valueuom
# mg/dL    766532
# Name: count, dtype: int64

# %%
print(bg_icu[bg_icu['value'] < 2656].shape)
print(bg_icu[bg_icu['value'] > 2656].shape)
# Out:
# (1814336, 11)
# (126, 11)

# %%
bg_icu = bg_icu[(bg_icu['value'] < 2656) & (bg_icu['value'] > 10)]

# %%
bg_icu.sort_values(by=['value','stay_id','charttime'], ascending=False).head()
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 815029     14486307  29356263  36290136           NaN 2188-01-11 02:59:00
# 815015     14486307  29356263  36290136           NaN 2187-12-29 14:09:00
# 1059308    15816613  20786142  37630991           NaN 2181-11-23 02:04:00
# 799544     14392310  22267572  30763023           NaN 2178-08-13 01:44:00
# 990820     15465739  28798031  38185691           NaN 2137-03-14 17:18:00
#
#                   storetime  itemid   value  valuenum valueuom  warning
# 815029  2188-01-11 05:32:00  220621  2650.0    2650.0    mg/dL        1
# 815015  2187-12-29 15:49:00  220621  2600.0    2600.0    mg/dL        1
# 1059308 2181-11-23 03:25:00  220621  2474.0    2474.0    mg/dL        1
# 799544  2178-08-13 02:51:00  220621  2440.0    2440.0    mg/dL        1
# 990820  2137-03-14 20:33:00  220621  2323.0    2323.0    mg/dL        1

# %%
counts = bg_icu['stay_id'].value_counts()
valid_stays = counts[(counts >= 2)].index
bg_icu = bg_icu[bg_icu['stay_id'].isin(valid_stays)]
bg_icu['stay_id'].value_counts()
# Out:
# stay_id
# 30359303    1274
# 33576993     961
# 33566920     835
# 39510663     787
# 32380519     783
#             ...
# 33381080       2
# 33779641       2
# 36202456       2
# 32428829       2
# 31107990       2
# Name: count, Length: 84895, dtype: int64

# %%
counts = bg_icu['stay_id'].value_counts()
valid_stays = counts[(counts >= 7)].index
copy = bg_icu[bg_icu['stay_id'].isin(valid_stays)].copy()

# %%
copy.sort_values(by=['stay_id','charttime'], ascending=True).head(20)
# Out:
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 449293    12466550  23998182  30000153           NaN 2174-09-29 13:27:00
# 449294    12466550  23998182  30000153           NaN 2174-09-29 14:07:00
# 449295    12466550  23998182  30000153           NaN 2174-09-29 15:37:00
# 449296    12466550  23998182  30000153           NaN 2174-09-29 16:05:00
# 449288    12466550  23998182  30000153        4477.0 2174-09-29 20:00:00
# 449289    12466550  23998182  30000153        4477.0 2174-09-30 00:35:00
# 449297    12466550  23998182  30000153           NaN 2174-09-30 03:34:00
# 449290    12466550  23998182  30000153       46354.0 2174-09-30 13:00:00
# 449291    12466550  23998182  30000153       78421.0 2174-09-30 20:00:00
# 449292    12466550  23998182  30000153       78421.0 2174-10-01 02:00:00
# 578345    13180007  27543152  30000213       94603.0 2162-06-21 06:00:00
# 578346    13180007  27543152  30000213       94603.0 2162-06-21 07:00:00
# 578342    13180007  27543152  30000213       49246.0 2162-06-21 07:45:00
# 578343    13180007  27543152  30000213       49246.0 2162-06-21 08:15:00
# 578351    13180007  27543152  30000213           NaN 2162-06-21 14:02:00
# 578352    13180007  27543152  30000213           NaN 2162-06-21 14:13:00
# 578344    13180007  27543152  30000213       49246.0 2162-06-21 18:00:00
# 578353    13180007  27543152  30000213           NaN 2162-06-21 20:43:00
# 578347    13180007  27543152  30000213       94603.0 2162-06-21 22:00:00
# 578354    13180007  27543152  30000213           NaN 2162-06-22 04:00:00
#
#                  storetime  itemid  value  valuenum valueuom  warning
# 449293 2174-09-29 13:30:00  226537  158.0     158.0    mg/dL        1
# 449294 2174-09-29 14:09:00  226537  176.0     176.0    mg/dL        1
# 449295 2174-09-29 16:45:00  220621  192.0     192.0    mg/dL        1
# 449296 2174-09-29 16:06:00  226537  175.0     175.0    mg/dL        1
# 449288 2174-09-29 21:11:00  226537  185.0     185.0      NaN        0
# 449289 2174-09-30 00:56:00  226537  145.0     145.0      NaN        0
# 449297 2174-09-30 04:46:00  220621  144.0     144.0    mg/dL        1
# 449290 2174-09-30 13:55:00  225664  139.0     139.0      NaN        0
# 449291 2174-09-30 20:56:00  225664  137.0     137.0      NaN        0
# 449292 2174-10-01 02:22:00  225664  136.0     136.0      NaN        0
# 578345 2162-06-21 05:59:00  225664  125.0     125.0      NaN        0
# 578346 2162-06-21 06:43:00  225664  108.0     108.0      NaN        0
# 578342 2162-06-21 08:22:00  225664   97.0      97.0      NaN        0
# 578343 2162-06-21 08:22:00  225664  156.0     156.0      NaN        0
# 578351 2162-06-21 14:54:00  220621  176.0     176.0    mg/dL        1
# 578352 2162-06-21 14:16:00  226537  171.0     171.0    mg/dL        1
# 578344 2162-06-21 18:38:00  225664  164.0     164.0      NaN        0
# 578353 2162-06-21 21:46:00  220621  192.0     192.0    mg/dL        1
# 578347 2162-06-21 22:03:00  225664  225.0     225.0      NaN        0
# 578354 2162-06-22 05:23:00  220621  275.0     275.0    mg/dL        1

# %% [markdown]
# The below code just calculates the average time between BG measurements across all ICU stays. Is **not** required to be run for the training or preprocessing. It just provides justification for the bin size used for the dataset.

# %%
icu_stays = bg_icu['stay_id'].unique()
all_gaps = []
for stay_id in icu_stays:
    # Gets the specific ICU stay data
    df_stay = bg_icu.loc[bg_icu['stay_id'] == stay_id].sort_values(by=['charttime']).reset_index(drop=True)

    df_stay['gap'] = df_stay['charttime'].diff()

    # Convert that to hours
    df_stay['gap_hours'] = df_stay['gap'].dt.total_seconds() / 3600

    # drop the first NaN (diff for the very first row) and any other NaNs
    stay_gaps = df_stay['gap_hours'].dropna().tolist()
    all_gaps.extend(stay_gaps)

#  Now all_gaps is a flat list of every gap within each ICU stay
all_gaps = np.array(all_gaps, dtype=np.float32)

# Compute statistics
median_gap = np.median(all_gaps)
mean_gap   = all_gaps.mean()
# Averaged mean
print(mean_gap)
print(median_gap)
# Out:
# 4.363479
# 3.4

# %%
plt.hist(all_gaps, bins=5)
plt.xlabel("Gap between readings (hours)")
plt.ylabel("Count")
plt.title("Distribution of in-stay measurement gaps")
plt.show()

# %%
qs = [0.01, 0.25, 0.5 , 0.75, 0.99]
quantile_values = np.quantile(all_gaps, qs)

for q, val in zip(qs, quantile_values):
    print(f"{q:.2%} quantile → {val:.2f} hours")
# Out:
# 1.00% quantile → 0.02 hours
# 25.00% quantile → 1.00 hours
# 50.00% quantile → 3.40 hours
# 75.00% quantile → 6.00 hours
# 99.00% quantile → 24.38 hours

# %%
bg_icu['subject_id'].nunique()
# Out:
# 60089

# %% [markdown]
# # Split Dataset into Training, Validation and Testing Datasets

# %%
# Get unique patient ids
unique_subjects = bg_icu['subject_id'].unique()

train_subjects, test_subjects = train_test_split(unique_subjects, test_size=0.2, random_state=seed)
train_subjects, test_subjects
# Out:
# (array([16710356, 13201095, 15796318, ..., 10931606, 14759494, 12790067],
#        dtype=int64),
#  array([13268396, 14744186, 16635499, ..., 16774869, 10123699, 17858582],
#        dtype=int64))

# %%
train_subjects, val_subjects = train_test_split(train_subjects, test_size=0.25, random_state=seed)

# %%
bg_icu['subject_id'].isin(test_subjects).sum()
# Out:
# 365401

# %%
bg_icu['subject_id'].isin(train_subjects).sum()
# Out:
# 1076450

# %%
bg_icu['valueuom'].isna().sum()
# Out:
# 1047207

# %% [markdown]
# ### Creating sequenced data

# %% [markdown]
# Here we create the data to be fed into the model. Each row of data in the X datasets is a sequence of BG measurements. The Y datasets contain a BG reading that follows directly from that sequence after.
#
# The approach we took is so that a sequence of measurements (starting from the first) is created of certain length from each ICU admission, which is taken as the X, and the following value after the sequence is taken as the Y. Then the window is slid over by one so that the sequence is slightly different, creating a new X value and a new following Y value. This process is repeated until the end of the ICU admission measurement sequence is reached, then a new ICU admission is chosen, until all ICU admissions have had their sequences recorded.

# %%
df_train = bg_icu[bg_icu['subject_id'].isin(train_subjects)]
df_train.head()
# Out:
#     subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 7     10000980  26913865  39765666       64209.0 2189-06-27 10:00:00
# 8     10000980  26913865  39765666       64209.0 2189-06-27 16:00:00
# 12    10001725  25563031  31205490       67214.0 2110-04-11 17:30:00
# 13    10001725  25563031  31205490           NaN 2110-04-11 18:02:00
# 14    10001725  25563031  31205490           NaN 2110-04-12 02:59:00
#
#              storetime  itemid  value  valuenum valueuom  warning
# 7  2189-06-27 10:10:00  225664  110.0     110.0      NaN        0
# 8  2189-06-27 16:24:00  225664  109.0     109.0      NaN        0
# 12 2110-04-11 17:32:00  225664  161.0     161.0      NaN        0
# 13 2110-04-11 18:53:00  220621  146.0     146.0    mg/dL        1
# 14 2110-04-12 03:47:00  220621  152.0     152.0    mg/dL        1

# %%
df_val = bg_icu[bg_icu['subject_id'].isin(val_subjects)]
df_val.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 1    10000690  25860671  37081114       84407.0 2150-11-04 10:00:00
# 2    10000690  25860671  37081114           NaN 2150-11-03 02:56:00
# 3    10000690  25860671  37081114           NaN 2150-11-04 03:03:00
# 4    10000690  25860671  37081114           NaN 2150-11-04 17:54:00
# 5    10000690  25860671  37081114           NaN 2150-11-05 05:36:00
#
#             storetime  itemid  value  valuenum valueuom  warning
# 1 2150-11-04 09:39:00  225664  117.0     117.0      NaN        0
# 2 2150-11-03 04:22:00  220621   77.0      77.0    mg/dL        0
# 3 2150-11-04 03:44:00  220621   84.0      84.0    mg/dL        0
# 4 2150-11-04 18:41:00  220621  120.0     120.0    mg/dL        1
# 5 2150-11-05 06:28:00  220621  107.0     107.0    mg/dL        1

# %%
df_test = bg_icu[bg_icu['subject_id'].isin(test_subjects)]
df_test.head()
# Out:
#     subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 33    10002013  23581541  39060235        5808.0 2160-05-19 01:00:00
# 34    10002013  23581541  39060235        5808.0 2160-05-19 02:15:00
# 35    10002013  23581541  39060235        8947.0 2160-05-19 16:00:00
# 36    10002013  23581541  39060235       28759.0 2160-05-18 17:00:00
# 37    10002013  23581541  39060235       28759.0 2160-05-18 19:00:00
#
#              storetime  itemid  value  valuenum valueuom  warning
# 33 2160-05-19 01:09:00  225664  119.0     119.0      NaN        0
# 34 2160-05-19 02:17:00  225664  107.0     107.0      NaN        0
# 35 2160-05-19 16:04:00  225664  236.0     236.0      NaN        0
# 36 2160-05-18 17:06:00  225664  154.0     154.0      NaN        0
# 37 2160-05-18 18:51:00  225664  179.0     179.0      NaN        0

# %%
df_train.sort_values(by=['subject_id','hadm_id','charttime'])
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 7          10000980  26913865  39765666       64209.0 2189-06-27 10:00:00
# 8          10000980  26913865  39765666       64209.0 2189-06-27 16:00:00
# 12         10001725  25563031  31205490       67214.0 2110-04-11 17:30:00
# 13         10001725  25563031  31205490           NaN 2110-04-11 18:02:00
# 14         10001725  25563031  31205490           NaN 2110-04-12 02:59:00
# ...             ...       ...       ...           ...                 ...
# 1814458    19999987  23865745  36195440       69532.0 2145-11-03 08:00:00
# 1814456    19999987  23865745  36195440       68756.0 2145-11-03 20:00:00
# 1814457    19999987  23865745  36195440       68756.0 2145-11-04 02:00:00
# 1814461    19999987  23865745  36195440           NaN 2145-11-04 05:01:00
# 1814459    19999987  23865745  36195440       96092.0 2145-11-04 08:00:00
#
#                   storetime  itemid  value  valuenum valueuom  warning
# 7       2189-06-27 10:10:00  225664  110.0     110.0      NaN        0
# 8       2189-06-27 16:24:00  225664  109.0     109.0      NaN        0
# 12      2110-04-11 17:32:00  225664  161.0     161.0      NaN        0
# 13      2110-04-11 18:53:00  220621  146.0     146.0    mg/dL        1
# 14      2110-04-12 03:47:00  220621  152.0     152.0    mg/dL        1
# ...                     ...     ...    ...       ...      ...      ...
# 1814458 2145-11-03 07:58:00  225664  122.0     122.0      NaN        0
# 1814456 2145-11-03 20:00:00  225664  105.0     105.0      NaN        0
# 1814457 2145-11-04 05:07:00  225664  112.0     112.0      NaN        0
# 1814461 2145-11-04 05:51:00  220621  100.0     100.0    mg/dL        0
# 1814459 2145-11-04 08:11:00  225664  127.0     127.0      NaN        0
#
# [1076450 rows x 11 columns]

# %%
df_train['stay_id'].value_counts().describe()
# Out:
# count    50862.000000
# mean        21.164130
# std         37.216863
# min          2.000000
# 25%          4.000000
# 50%         10.000000
# 75%         23.000000
# max       1274.000000
# Name: count, dtype: float64

# %%
# Get counts
stay_counts = df_train['stay_id'].value_counts()

# Plot histogram of those counts
sns.boxplot(stay_counts) 

plt.ylabel('Number of BG measurements per stay_id')
plt.title('Distribution of ICU stay measurement counts')
plt.show()

# %%
counts = df_train['stay_id'].value_counts()

Q1 = counts.quantile(0.25)
Q3 = counts.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

valid_stays = counts[(counts >= lower_bound) & (counts <= upper_bound)].index

df_filtered = df_train[df_train['stay_id'].isin(valid_stays)]
# Plot boxplot of those counts
sns.boxplot(df_filtered['stay_id'].value_counts())

plt.ylabel('Number of BG measurements per stay_id')
plt.title('Distribution of ICU stay measurement counts')
plt.show()

# %%
train_icu_stays = df_train['stay_id'].unique()

# %%
df_train['stay_id'].value_counts()
# Out:
# 30359303    1274
# 33566920     835
# 39510663     787
# 32380519     783
# 31010136     734
#             ...
# 35206016       2
# 37216596       2
# 38214855       2
# 32406434       2
# 39765666       2
# Name: stay_id, Length: 50862, dtype: int64

# %%
df_train.reset_index(drop=True)[df_train.reset_index(drop=True)['stay_id']==33566920]
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 1061984    19874859  23391430  33566920         701.0 2169-04-12 09:00:00
# 1061985    19874859  23391430  33566920         701.0 2169-04-12 10:00:00
# 1061986    19874859  23391430  33566920         701.0 2169-04-12 13:00:00
# 1061987    19874859  23391430  33566920         701.0 2169-04-12 15:00:00
# 1061988    19874859  23391430  33566920         701.0 2169-04-12 17:00:00
# ...             ...       ...       ...           ...                 ...
# 1062814    19874859  23391430  33566920           NaN 2169-05-19 04:14:00
# 1062815    19874859  23391430  33566920           NaN 2169-05-20 03:55:00
# 1062816    19874859  23391430  33566920           NaN 2169-05-21 02:09:00
# 1062817    19874859  23391430  33566920           NaN 2169-05-22 01:27:00
# 1062818    19874859  23391430  33566920           NaN 2169-05-23 01:51:00
#
#                   storetime  itemid  value  valuenum valueuom  warning
# 1061984 2169-04-12 09:45:00  225664  133.0     133.0      NaN        0
# 1061985 2169-04-12 10:09:00  225664  132.0     132.0      NaN        0
# 1061986 2169-04-12 13:36:00  225664  118.0     118.0      NaN        0
# 1061987 2169-04-12 15:09:00  225664  138.0     138.0      NaN        0
# 1061988 2169-04-12 17:01:00  225664  132.0     132.0      NaN        0
# ...                     ...     ...    ...       ...      ...      ...
# 1062814 2169-05-19 05:11:00  220621  109.0     109.0    mg/dL        1
# 1062815 2169-05-20 05:02:00  220621  150.0     150.0    mg/dL        1
# 1062816 2169-05-21 03:18:00  220621  151.0     151.0    mg/dL        1
# 1062817 2169-05-22 02:20:00  220621   98.0      98.0    mg/dL        0
# 1062818 2169-05-23 02:47:00  220621   96.0      96.0    mg/dL        0
#
# [835 rows x 11 columns]

# %% [markdown]
# ### Hyperparameters

# %%
FREQ       = '2H'           # 2-hour bins
MAX_HOURS  = 48
STEPS      = MAX_HOURS // 2 # 48 h ÷ 2 h = 24 bins
L          = 6               # look-back  steps (12 hours of history)
H          = 1               # look-ahead steps (direct subsequent prediction)
SENTINEL   = -1.0            # value the Masking layer will ignore

# %% [markdown]
# ### Here we resample the data to ensure there is a row for every timestep interval of 2 hours.

# %%
def resample_one(stay_df):
    # Return length=STEPS array of 2 hour means (with possibly NaN data).

    # Converts ICU_stay data to a format where the data is either combined into a
    # mean for every timestep of 2 hours, or a gap is left as a NaN value
    s = (stay_df
         .set_index('charttime')['value']
         .resample(FREQ).mean())

    # Sets the length of the data to be STEPS length long, cutting off any
    # data that goes beyond that many steps
    idx = pd.date_range(start=s.index.min(), periods=STEPS, freq=FREQ)
    return s.reindex(idx).values

# %%
def make_Xy(df_subset, scaler=None, fit_scaler=False):

    X_stays = []
    # Iterate through data, converting all icu_stay data into their own dataframes
    # then passing it to the resampling method
    for _, g in (df_subset
                 .sort_values(['stay_id', 'charttime'])
                 .groupby('stay_id')):
        X_stays.append(resample_one(g))

    # Converts all icu_stay glucose value series sequences to numpy 2-d array, of shape (N_STAYS, steps)
    X_stays = np.stack(X_stays)

    # Normalise using z-scores

    # Ensures scaler is created for training object, so it creates the mean and std of training data,
    # then fits test and val data to it
    if scaler is None:
        scaler = StandardScaler()
    # Converts all data to flat shape so mean and std can be computed in a single vector
    flat = X_stays.reshape(-1, 1)
    mask = ~np.isnan(flat)

    # Tensorflow fit() method expects a 2D array of shape
    real_vals = flat[mask].reshape(-1, 1)


    if fit_scaler:
        # Learn the variables of only the real values (non-NaN)
        scaler.fit(real_vals)
    # Apply the learned transformation to the actual values
    flat[mask] = scaler.transform(real_vals).ravel()
    X_stays = flat.reshape(X_stays.shape)    # back to (N_stays, STEPS)

    # Sliding window
    windows, targets = [], []
    for stay in X_stays:
        # Window slides across every point so that the entire horizon of the ICU stay is included once
        for t0 in range(0, STEPS - L - H + 1):
            x_win = stay[t0 : t0 + L]         # Look-back window
            y_val = stay[t0 + L + H - 1]      # Value following window
            if not np.isnan(y_val):           # ensure that the final y value is an actual value
                windows.append(x_win)
                targets.append(y_val)

    # [..., None] shorthand adds an extra 3rd dimension so it can be fitted to the tensorflow LSTM
    X = np.array(windows)[..., None]
    y = np.array(targets,  dtype='float32')

    # replace NaN inside X with sentinel so Masking works
    X[np.isnan(X)] = SENTINEL
    return X.astype('float32'), y, scaler

# %%
X_train, y_train, scaler = make_Xy(df_train,
                                   scaler=None,
                                   fit_scaler=True)
X_val, y_val, _ = make_Xy(df_val,
                          scaler=scaler,
                          fit_scaler=False)
X_test, y_test, _ = make_Xy(df_test,
                            scaler=scaler,
                            fit_scaler=False)

# %%
print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape,   y_val.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (245319, 6, 1) (245319,)
# Val  : (81839, 6, 1) (81839,)
# Test : (83310, 6, 1) (83310,)

# %%
BATCH = 64
def make_ds(X, y, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if shuffle:
        ds = ds.shuffle(len(y), seed=seed)
    return ds.batch(BATCH).prefetch(tf.data.AUTOTUNE)

# %%
ds_train = make_ds(X_train, y_train, shuffle=True)
ds_val   = make_ds(X_val,   y_val,   shuffle=False)
ds_test  = make_ds(X_test,  y_test,  shuffle=False)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Masking(mask_value=SENTINEL, input_shape=(L, 1)),
    tf.keras.layers.LSTM(64),
    # A dense layer here is necessary, as each hidden state output, which is
    # the output of an LSTM unit is only within the range of a tanh activation function,
    # so further transformation is needed
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)                   # regression
])

model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_1 (Masking)         (None, 6, 1)              0
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 19,009
# Trainable params: 19,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create directory if it doesn't exist
os.makedirs('models', exist_ok=True)

# %%
#  Create a checkpoint callback
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath='models/model_epoch_{epoch:02d}.h5',
    save_freq='epoch',                       # save after each epoch
    save_weights_only=False,                 # save the entire model (architecture + weights + optimizer state)
    verbose=1
)

history = model.fit(
    ds_train,
    epochs=100,
    validation_data=ds_val,
    callbacks=[checkpoint_cb],
    verbose=1
)

test_loss, test_mae = model.evaluate(ds_test)
print(f"Test RMSE = {np.sqrt(test_loss):.2f}   |   MAE = {test_mae:.2f}")
# Out:
# Epoch 1/100
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.4177 - mae: 0.4189
# Epoch 1: saving model to models\model_epoch_01.h5
# 3834/3834 [==============================] - 22s 5ms/step - loss: 0.4176 - mae: 0.4189 - val_loss: 0.4269 - val_mae: 0.4163
# Epoch 2/100
# 3832/3834 [============================>.] - ETA: 0s - loss: 0
100
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.3922 - mae: 0.4054
# Epoch 80: saving model to models\model_epoch_80.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3922 - mae: 0.4054 - val_loss: 0.4318 - val_mae: 0.4097
# Epoch 81/100
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.3921 - mae: 0.4053
# Epoch 81: saving model to models\model_epoch_81.h5
# 3834/3834 [==============================] - 42s 11ms/step - loss: 0.3920 - mae: 0.4053 - val_loss: 0.4323 - val_mae: 0.4157
# Epoch 82/100
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.3917 - mae: 0.4052
# Epoch 82: saving model to models\model_epoch_82.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3917 - mae: 0.4052 - val_loss: 0.4321 - val_mae: 0.4122
# Epoch 83/100
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.3916 - mae: 0.4052
# Epoch 83: saving model to models\model_epoch_83.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3916 - mae: 0.4052 - val_loss: 0.4334 - val_mae: 0.4128
# Epoch 84/100
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.3911 - mae: 0.4048
# Epoch 84: saving model to models\model_epoch_84.h5
# 3834/3834 [==============================] - 40s 10ms/step - loss: 0.3910 - mae: 0.4048 - val_loss: 0.4325 - val_mae: 0.4097
# Epoch 85/100
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.3910 - mae: 0.4049
# Epoch 85: saving model to models\model_epoch_85.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3910 - mae: 0.4049 - val_loss: 0.4324 - val_mae: 0.4091
# Epoch 86/100
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.3907 - mae: 0.4047
# Epoch 86: saving model to models\model_epoch_86.h5
# 3834/3834 [==============================] - 41s 11ms/step - loss: 0.3906 - mae: 0.4046 - val_loss: 0.4331 - val_mae: 0.4102
# Epoch 87/100
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.3903 - mae: 0.4045
# Epoch 87: saving model to models\model_epoch_87.h5
# 3834/3834 [==============================] - 38s 10ms/step - loss: 0.3903 - mae: 0.4044 - val_loss: 0.4341 - val_mae: 0.4128
# Epoch 88/100
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.3903 - mae: 0.4044
# Epoch 88: saving model to models\model_epoch_88.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3902 - mae: 0.4044 - val_loss: 0.4339 - val_mae: 0.4141
# Epoch 89/100
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.3901 - mae: 0.4044
# Epoch 89: saving model to models\model_epoch_89.h5
# 3834/3834 [==============================] - 40s 10ms/step - loss: 0.3898 - mae: 0.4043 - val_loss: 0.4353 - val_mae: 0.4130
# Epoch 90/100
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.3897 - mae: 0.4043
# Epoch 90: saving model to models\model_epoch_90.h5
# 3834/3834 [==============================] - 38s 10ms/step - loss: 0.3895 - mae: 0.4042 - val_loss: 0.4333 - val_mae: 0.4130
# Epoch 91/100
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.3893 - mae: 0.4041
# Epoch 91: saving model to models\model_epoch_91.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3893 - mae: 0.4040 - val_loss: 0.4326 - val_mae: 0.4128
# Epoch 92/100
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.3891 - mae: 0.4039
# Epoch 92: saving model to models\model_epoch_92.h5
# 3834/3834 [==============================] - 39s 10ms/step - loss: 0.3890 - mae: 0.4039 - val_loss: 0.4340 - val_mae: 0.4113
# Epoch 93/100
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.3891 - mae: 0.4040
# Epoch 93: saving model to models\model_epoch_93.h5
# 3834/3834 [==============================] - 42s 11ms/step - loss: 0.3890 - mae: 0.4040 - val_loss: 0.4349 - val_mae: 0.4125
# Epoch 94/100
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.3886 - mae: 0.4037
# Epoch 94: saving model to models\model_epoch_94.h5
# 3834/3834 [==============================] - 40s 10ms/step - loss: 0.3885 - mae: 0.4036 - val_loss: 0.4349 - val_mae: 0.4110
# Epoch 95/100
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.3882 - mae: 0.4035
# Epoch 95: saving model to models\model_epoch_95.h5
# 3834/3834 [==============================] - 44s 11ms/step - loss: 0.3883 - mae: 0.4036 - val_loss: 0.4371 - val_mae: 0.4167
# Epoch 96/100
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.3879 - mae: 0.4036
# Epoch 96: saving model to models\model_epoch_96.h5
# 3834/3834 [==============================] - 45s 12ms/step - loss: 0.3880 - mae: 0.4036 - val_loss: 0.4348 - val_mae: 0.4126
# Epoch 97/100
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.3878 - mae: 0.4033
# Epoch 97: saving model to models\model_epoch_97.h5
# 3834/3834 [==============================] - 45s 12ms/step - loss: 0.3879 - mae: 0.4033 - val_loss: 0.4375 - val_mae: 0.4120
# Epoch 98/100
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.3874 - mae: 0.4031
# Epoch 98: saving model to models\model_epoch_98.h5
# 3834/3834 [==============================] - 44s 12ms/step - loss: 0.3874 - mae: 0.4032 - val_loss: 0.4387 - val_mae: 0.4159
# Epoch 99/100
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.3874 - mae: 0.4031
# Epoch 99: saving model to models\model_epoch_99.h5
# 3834/3834 [==============================] - 43s 11ms/step - loss: 0.3874 - mae: 0.4032 - val_loss: 0.4365 - val_mae: 0.4136
# Epoch 100/100
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.3870 - mae: 0.4031
# Epoch 100: saving model to models\model_epoch_100.h5
# 3834/3834 [==============================] - 38s 10ms/step - loss: 0.3869 - mae: 0.4030 - val_loss: 0.4359 - val_mae: 0.4134
# 1302/1302 [==============================] - 4s 3ms/step - loss: 0.3962 - mae: 0.4117
# Test RMSE = 0.63   |   MAE = 0.41

# %%
std = scaler.scale_[0]      # std that StandardScaler learned
rmse_mgdl = np.sqrt(test_loss) * std
mae_mgdl  = test_mae * std

print(f"True RMSE  = {rmse_mgdl:.1f} mg/dL")
print(f"True  MAE  = {mae_mgdl:.1f} mg/dL")
# Out:
# True RMSE  = 40.2 mg/dL
# True  MAE  = 26.3 mg/dL

# %%
y_pred_scaled = model.predict(ds_test).ravel()
y_true_scaled = y_test

# Inverse-transform
y_pred = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()
y_true = scaler.inverse_transform(y_true_scaled.reshape(-1, 1)).ravel()

from sklearn.metrics import r2_score
r2 = r2_score(y_true, y_pred)
print(f"R^2 = {r2:.4f}")
# Out:
# 1302/1302 [==============================] - 5s 2ms/step
# R^2 = 0.5235
